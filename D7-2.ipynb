# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  seaborn import scatterplot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings('ignore')

# %%
cars=pd.read_csv(r"C:\Users\satya\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
sns.distplot(cars['HP'])
sns.distplot(cars['MPG'])
sns.distplot(cars['VOL'])
sns.distplot(cars['SP'])
sns.distplot(cars['WT'])
plt.show()

# %%
sns.distplot(x=cars['WT'])
plt.title('Distriution of Weight of vehicles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.distplot(x=cars['MPG'])
plt.title('Distriution of Millage Per Gallon')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.distplot(x=cars['VOL'])
plt.title('Distriution of Volume')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.distplot(x=cars['SP'])
plt.title('Distriution of SP')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.distplot(x=cars['HP'])
plt.title('Distriution of HorsePower')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
plt.title("Box plot for MPG")
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.title("Box plot for HP")
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.title("Box plot for SP")
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.title("Box plot for VOL")
plt.show()

# %%
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
scatterplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
scatterplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.barplot(x=cars['HP'],y=cars['WT'],color='red')
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.barplot(x=cars['HP'],y=cars['VOL'],color='green')
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.barplot(x=cars['HP'],y=cars['SP'],color='blue')
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
#sns.scatterplot(x=cars['WT'],y=cars['WT'])

# %%
sns.scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x=cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
cars[['HP','WT','VOL','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),2)
# Out:
#           HP    MPG    VOL     SP     WT
# count  81.00  81.00  81.00  81.00  81.00
# mean   -0.00  34.42   0.00   0.00   0.00
# std     1.01   9.13   1.01   1.01   1.01
# min    -1.21  12.10  -2.20  -1.56  -2.24
# 25%    -0.59  27.86  -0.44  -0.55  -0.38
# 50%    -0.31  35.15   0.10  -0.24   0.04
# 75%     0.40  39.53   0.64   0.35   0.67
# max     3.60  53.70   2.76   3.41   2.76

# %%
import statsmodels.formula.api as smf
ml_v=smf.ols('MPG~VOL',data=cars).fit()
np.round(ml_v.rsquared,2)
# Out:
# 0.28

# %%
ml_v.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
ml_w=smf.ols('MPG~WT',data=cars).fit()
np.round(ml_w.rsquared,2)
# Out:
# 0.28

# %%
ml_s=smf.ols('MPG~SP',data=cars).fit()
np.round(ml_s.rsquared,2)
# Out:
# 0.47

# %%
ml_h=smf.ols('MPG~HP',data=cars).fit()
np.round(ml_h.rsquared,2)
# Out:
# 0.53

# %%
ml_s.params
# Out:
# Intercept    34.422076
# SP           -6.235589
# dtype: float64

# %%
ml_h.params
# Out:
# Intercept    34.422076
# HP           -6.579653
# dtype: float64

# %%
ml_w.params
# Out:
# Intercept    34.422076
# WT           -4.780288
# dtype: float64

# %%
ml_all=smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()
#np.round(ml_all.rsquared,2)

# %%
#ml_all=smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()
np.round(ml_all.rsquared,2)
# Out:
# 0.77

# %%
ml_all=smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()
np.round(ml_all.rsquared,2)
# Out:
# 0.77

# %%
ml_all.params
# Out:
# Intercept    34.422076
# WT            2.982842
# VOL          -7.448031
# SP            5.575816
# HP          -11.660955
# dtype: float64

# %%
np.round(ml_all.params,2)
# Out:
# Intercept    34.42
# WT            2.98
# VOL          -7.45
# SP            5.58
# HP          -11.66
# dtype: float64
